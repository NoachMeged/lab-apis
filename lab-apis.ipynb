# %% [markdown]
# # Lab | APIs

# %% [markdown]
# In order to use the `Spotify` API (`SpotiPy`), create an account in `Spotify` and follow [these](https://developer.spotify.com/documentation/general/guides/app-settings/) steps.

# %% [markdown]
# ## Authentication and initializing the API

# %% [markdown]
# Save your client ID and your client secret in your preferred way, and read it or load it into the following variables:

# %%
CLIENT_ID = "4109b2d9f5014671863bb2df1d1fbdd3"
CLIENT_SECRET = "5cb719fae80c4191a9c0b288f51bfe50"

# %%
# If you havent done so, install the spotipy wrapper
# !pip install spotipy

# %% [markdown]
# Once you have done it, we will start initializing the API.

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=CLIENT_ID,
                                                           client_secret=CLIENT_SECRET))

# %% [markdown]
# ## Using the search method

# %% [markdown]
# Now, let's use the search method by introducing a "query". For example, let's try searching for "Lady Gaga":

# %%
results = sp.search(q='Lady Gaga', limit=50)
results
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?offset=0&limit=50&query=Lady%20Gaga&type=track',
#   'limit': 50,
#   'next': 'https://api.spotify.com/v1/search?offset=50&limit=50&query=Lady%20Gaga&type=track',
#   'offset': 0,
#   'previous': None,
#   'total': 926,
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#        'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#        'id': '1HY2Jd0NmPuamShAr6KMms',
#        'name': 'Lady Gaga',
#        'type': 'artist',
#        'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#      'available_markets': ['AR',
#       'AU',
#       'AT',
#       'BE',
#       'BO',
#       'BR',
#       'BG',
#       'CA',
#       'CL',
#       'CO',
#       'CR',
#       'CY',
#       'CZ',
#       'DK',
#       'DO',
#       'DE',
#       'EC',
#       'EE',
#       'SV',
#       'FI',
#       'FR',
#       'GR',
# ...

# %%
results.keys() # We can see that we only have tracks
# Out:
# dict_keys(['tracks'])

# %%
results["tracks"].keys() # Let's check the values
# Out:
# dict_keys(['href', 'limit', 'next', 'offset', 'previous', 'total', 'items'])

# %%
results["tracks"]["href"] # Query we have searched
# Out:
# 'https://api.spotify.com/v1/search?offset=0&limit=50&query=Lady%20Gaga&type=track'

# %%
results["tracks"]["items"] #items (actual tracks)
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#      'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#      'id': '1HY2Jd0NmPuamShAr6KMms',
#      'name': 'Lady Gaga',
#      'type': 'artist',
#      'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#    'available_markets': ['AR',
#     'AU',
#     'AT',
#     'BE',
#     'BO',
#     'BR',
#     'BG',
#     'CA',
#     'CL',
#     'CO',
#     'CR',
#     'CY',
#     'CZ',
#     'DK',
#     'DO',
#     'DE',
#     'EC',
#     'EE',
#     'SV',
#     'FI',
#     'FR',
#     'GR',
#     'GT',
#     'HN',
#     'HK',
#     'HU',
#     'IS',
#     'IE',
#     'IT',
#     'LV',
#     'LT',
#     'LU',
#     'MY',
#     'MT',
#     'MX',
#     'NL',
#     'NZ',
#     'NI',
#     'NO',
#     'PA',
#     'PY',
#     'PE',
#     'PH',
#     'PL',
#     'PT',
#     'SG',
#     'SK',
#     'ES',
#     'CH',
#     'TW',
# ...

# %%
results["tracks"]["limit"]#Limit we have chosen
# Out:
# 50

# %%
results["tracks"]["next"] #link to the next page (next 50 tracks)
# Out:
# 'https://api.spotify.com/v1/search?offset=50&limit=50&query=Lady%20Gaga&type=track'

# %%
results["tracks"]["offset"] # Actual offset (starting point)
# Out:
# 0

# %%
results["tracks"]["previous"] #Previous search

# %%
results["tracks"]["total"] # Number of matches
# Out:
# 926

# %% [markdown]
# ## Exploring the tracks

# %%
results["tracks"]["items"][0] # Explore the first song
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#     'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#     'id': '1HY2Jd0NmPuamShAr6KMms',
#     'name': 'Lady Gaga',
#     'type': 'artist',
#     'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}],
#   'available_markets': ['AR',
#    'AU',
#    'AT',
#    'BE',
#    'BO',
#    'BR',
#    'BG',
#    'CA',
#    'CL',
#    'CO',
#    'CR',
#    'CY',
#    'CZ',
#    'DK',
#    'DO',
#    'DE',
#    'EC',
#    'EE',
#    'SV',
#    'FI',
#    'FR',
#    'GR',
#    'GT',
#    'HN',
#    'HK',
#    'HU',
#    'IS',
#    'IE',
#    'IT',
#    'LV',
#    'LT',
#    'LU',
#    'MY',
#    'MT',
#    'MX',
#    'NL',
#    'NZ',
#    'NI',
#    'NO',
#    'PA',
#    'PY',
#    'PE',
#    'PH',
#    'PL',
#    'PT',
#    'SG',
#    'SK',
#    'ES',
#    'CH',
#    'TW',
#    'TR',
#    'UY',
#    'US',
#    'GB',
#    'AD',
#    'LI',
# ...

# %%
results["tracks"]["items"][0].keys() # We will focus on album, artists, id, name, popularity, type and uri
# Out:
# dict_keys(['album', 'artists', 'available_markets', 'disc_number', 'duration_ms', 'explicit', 'external_ids', 'external_urls', 'href', 'id', 'is_local', 'is_playable', 'name', 'popularity', 'preview_url', 'track_number', 'type', 'uri'])

# %%
# Track artists
results["tracks"]["items"][0]["artists"]
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1HY2Jd0NmPuamShAr6KMms'},
#   'href': 'https://api.spotify.com/v1/artists/1HY2Jd0NmPuamShAr6KMms',
#   'id': '1HY2Jd0NmPuamShAr6KMms',
#   'name': 'Lady Gaga',
#   'type': 'artist',
#   'uri': 'spotify:artist:1HY2Jd0NmPuamShAr6KMms'}]

# %%
# Track artists names
for artist in results["tracks"]["items"][0]["artists"]:
    print(artist["name"])
# Out:
# Lady Gaga

# %%
# Track ID
results["tracks"]["items"][0]["id"]
# Out:
# '5ZLUm9eab8y3tqQ1OhQSHI'

# %%
# Track name
results["tracks"]["items"][0]["name"]
# Out:
# 'Abracadabra'

# %%
# Popularity index
results["tracks"]["items"][0]["popularity"]
# Out:
# 93

# %% [markdown]
# Spotify songs are identified by either a "url", a "uri", or an "id".
#
# - The `id` is an alphanumeric code, and it's the nuclear part of the identifier.
#
# - The `uri` contains "spotify:track" before the id. An uri is useful because it can be searched manually in the Spotify app.
#
# - The `url` is a link to the song on the Spotify web player.

# %%
results["tracks"]["items"][0]["uri"]
# Out:
# 'spotify:track:5ZLUm9eab8y3tqQ1OhQSHI'

# %% [markdown]
# ## Exercise 1: Discovering New Music through Your Favorite Artists
#
# **Objective:**
# Uncover new music by exploring the top tracks of your favorite artists and their related artists.
#
# **Instructions:**
#
# 1. **List Your Favorite Artists**:
#     - Make a list of your three favorite artists and store it in a variable named `artists`.
#     - Example: `artists = ["Los Fabulosos Cadillacs", "Manu Chao", "Muchachito Bombo Infierno"]`.
#
# 2. **Fetch Top Tracks**:
#     - Write a function named `get_top_tracks`.
#     - This function should accept an artist's name and return the name of the first 5 top tracks by that artist.
#     - Use the function `get_top_tracks` to get the first 5 top tracks for each artist in your `artists` list and store the results in a new list named `top_tracks_list`.
#
# 3. **Discover Related Artists**:
#     - Write a function named `find_related_artists`.
#     - This function should accept an artist's name and return the names of the first 5 artists related to the provided artist.
#     - Store the results in a list named `related_artists_list`.
#
# **Challenge:**
# Combine the above steps to create a playlist that includes the top tracks of your favorite artists and the top tracks of the artists related to them.

# %% [markdown]
# **Hint Section for 3. **Discover Related Artists**:**
#
# 1. **Getting Artist ID**:
#     - Remember that every artist on Spotify has a unique identifier: their `id`. To get the related artists, you first need to fetch the ID of the given artist.
#     - Consider using the `sp.search` method to query the artist's name. The method requires a `q` parameter, which is your query (in this case, the artist's name). It also has a `limit` parameter, which specifies the number of tracks it returns. In this case, 1 track is enough, since we just want the artist ID.
#     - Each track in the results has an associated 'artists' field. This field is a list containing details about all artists involved in that track.
#    - For most tracks, especially those by a single artist, this list will contain one artist. From this artist's details, you can extract the 'id' field, which is the unique identifier for that artist on Spotify.
#
#
# 3. **Fetching Related Artists**:
#     - Once you have the artist's ID, you can use another SpotiPy method to fetch related artists. Think about which SpotiPy method allows you to get related artists using an artist's ID. Here is the documentation link: https://spotipy.readthedocs.io/en/2.22.1/.
#     - This method will return a list of related artists. You'll need to extract the relevant details (artist names) from this list.
#
# 4. **Iterating for Multiple Artists**:
#     - Once you have a function that returns related artists names for one artist, you can use a list comprehension to apply this function to a list of artist names.
#
# 5. **Testing**:
#     - Always test your function with one artist name first. Once you're confident it works, then apply it to the entire list.
#
# Remember, the key is to break the problem down into manageable steps. Use the SpotiPy documentation as a resource to understand available methods and their return structures.

# %%
# !pip install requests

# %%
import requests
import base64

CLIENT_ID = "dd4776b20a1947b692250c764d2b1564"
CLIENT_SECRET = "7e10824397094006b6d54c2f9c65edb9"  # vervang dit met je echte secret

def get_access_token():
    auth_url = "https://accounts.spotify.com/api/token"
    auth_header = base64.b64encode(f"{CLIENT_ID}:{CLIENT_SECRET}".encode()).decode()
    
    headers = {
        "Authorization": f"Basic {auth_header}",
        "Content-Type": "application/x-www-form-urlencoded"
    }
    
    data = {
        "grant_type": "client_credentials"
    }
    
    response = requests.post(auth_url, headers=headers, data=data)
    
    if response.status_code == 200:
        return response.json().get("access_token")
    else:
        print("Error getting access token:", response.json())
        return None

ACCESS_TOKEN = get_access_token()
print("Access Token:", ACCESS_TOKEN)
# Out:
# Access Token: BQCcztnxMWWl4QzJg0CSYM2fMyTQWL0UBHqc5_iHv-ozNEEZWXx8WoqzGzKinzDpxSgT2Ghvws9n_xJdt4t_STRWq6PYk_tp1XdF4vCLc2QtoZtx4DQJICM-hJKxEm7AkNIToiEh9EQ

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# Set up credentials
CLIENT_ID = "dd4776b20a1947b692250c764d2b1564"
CLIENT_SECRET = "7e10824397094006b6d54c2f9c65edb9"

# Authenticate with Spotify
auth_manager = SpotifyClientCredentials(client_id=CLIENT_ID, client_secret=CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# List of artist names
artist_names = ["arik einstein", "zohar argov", "rob de nijs"]

# Search for each artist
results = [sp.search(q=name, limit=1, type="artist") for name in artist_names]

# Print the results
for name, result in zip(artist_names, results):
    items = result['artists']['items']
    if items:
        artist = items[0]
        print(f"{name.title()} ➤ {artist['name']} (Followers: {artist['followers']['total']})")
        print(f"  Spotify URL: {artist['external_urls']['spotify']}\n")
    else:
        print(f"{name.title()} ➤ No results found.\n")
# Out:
# Arik Einstein ➤ Arik Einstein (Followers: 509537)
#   Spotify URL: https://open.spotify.com/artist/16XberediOtO5CaMrx85cR
#
# Zohar Argov ➤ Zohar Argov (Followers: 65717)
#   Spotify URL: https://open.spotify.com/artist/3RUaBohZGA9vusdMDJBD1V
#
# Rob De Nijs ➤ Rob De Nijs (Followers: 127900)
#   Spotify URL: https://open.spotify.com/artist/3u84EkSPrJYO4n5cipED9K

# %%
import requests
import base64

CLIENT_ID = "dd4776b20a1947b692250c764d2b1564"
CLIENT_SECRET = "7e10824397094006b6d54c2f9c65edb9"

def get_access_token():
    auth_url = "https://accounts.spotify.com/api/token"
    auth_header = base64.b64encode(f"{CLIENT_ID}:{CLIENT_SECRET}".encode()).decode()

    headers = {
        "Authorization": f"Basic {auth_header}",
        "Content-Type": "application/x-www-form-urlencoded"
    }

    data = {
        "grant_type": "client_credentials"
    }

    response = requests.post(auth_url, headers=headers, data=data)
    if response.status_code == 200:
        return response.json().get("access_token")
    else:
        print("Error getting token:", response.text)
        return None

def get_artist_id(name, token):
    url = "https://api.spotify.com/v1/search"
    headers = {
        "Authorization": f"Bearer {token}"
    }
    params = {
        "q": name,
        "type": "artist",
        "limit": 1
    }

    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        data = response.json()
        items = data["artists"]["items"]
        if items:
            return items[0]["id"]
        else:
            print(f"Artist not found: {name}")
            return None
    else:
        print(f"Error searching artist {name}: {response.text}")
        return None

def get_top_tracks(artist_name, token, market="NL"):
    artist_id = get_artist_id(artist_name, token)
    if not artist_id:
        return []

    url = f"https://api.spotify.com/v1/artists/{artist_id}/top-tracks"
    headers = {
        "Authorization": f"Bearer {token}"
    }
    params = {
        "market": market  # required!
    }

    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        data = response.json()
        top_tracks = [track["name"] for track in data["tracks"][:5]]
        return top_tracks
    else:
        print(f"Error getting top tracks for {artist_name}: {response.text}")
        return []

# Access token ophalen
access_token = get_access_token()

# Artiestennamen
artist_names = ["arik einstein", "zohar argov", "rob de nijs"]

# Top 5 tracks per artiest
top_tracks_list = [get_top_tracks(name, access_token) for name in artist_names]

# Print resultaten
for artist, tracks in zip(artist_names, top_tracks_list):
    print(f"\nTop tracks for {artist.title()}:")
    for idx, track in enumerate(tracks, 1):
        print(f"{idx}. {track}")
# Out:
# Top tracks for Arik Einstein:
# 1. אני ואתה
# 2. גיטרה וכינור
# 3. סע לאט
# 4. יש בי אהבה
# 5. אהבה ממבט ראשון
#
# Top tracks for Zohar Argov:
# 1. הפרח בגני
# 2. צל עץ תמר ואור ירח
# 3. נכון להיום
# 4. בדד
# 5. אלינור
#
# Top tracks for Rob De Nijs:
# 1. Banger Hart
# 2. Het Werd Zomer
# 3. Malle Babbe
# 4. Zondag
# 5. Foto Van Vroeger

# %%
import requests
import base64

# Spotify API credentials
CLIENT_ID = "dd4776b20a1947b692250c764d2b1564"
CLIENT_SECRET = "7e10824397094006b6d54c2f9c65edb9"

def get_access_token():
    auth_url = "https://accounts.spotify.com/api/token"
    auth_header = base64.b64encode(f"{CLIENT_ID}:{CLIENT_SECRET}".encode()).decode()

    headers = {
        "Authorization": f"Basic {auth_header}",
        "Content-Type": "application/x-www-form-urlencoded"
    }

    data = {
        "grant_type": "client_credentials"
    }

    response = requests.post(auth_url, headers=headers, data=data)
    if response.status_code == 200:
        return response.json().get("access_token")
    else:
        print("Error getting token:", response.text)
        return None

def get_artist_id(name, token):
    url = "https://api.spotify.com/v1/search"
    headers = {
        "Authorization": f"Bearer {token}"
    }
    params = {
        "q": name,
        "type": "artist",
        "limit": 1
    }

    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        data = response.json()
        items = data["artists"]["items"]
        if items:
            return items[0]["id"]
        else:
            print(f"Artist not found: {name}")
            return None
    else:
        print(f"Error searching artist {name}: {response.text}")
        return None

def find_related_artists(artist_name, token):
    artist_id = get_artist_id(artist_name, token)
    if not artist_id:
        return []

    url = f"https://api.spotify.com/v1/artists/{artist_id}/related-artists"
    headers = {
        "Authorization": f"Bearer {token}"
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        data = response.json()
        related_artists = [artist["name"] for artist in data["artists"][:5]]
        return related_artists
    else:
        print(f"Error getting related artists for {artist_name}: {response.text}")
        return []

# Haal een access token op
access_token = get_access_token()

# Artiesten waarvan we gerelateerde artiesten willen vinden
artist_names = ["Arik Einstein", "Zohar Argov", "Rob de Nijs"]

# Zoek de gerelateerde artiesten
related_artists_list = [find_related_artists(name, access_token) for name in artist_names]

# Print resultaten
for artist, related in zip(artist_names, related_artists_list):
    print(f"\nGerelateerde artiesten voor {artist}:")
    for idx, related_artist in enumerate(related, 1):
        print(f"{idx}. {related_artist}")
# Out:
# Error getting related artists for Arik Einstein: {"error": {"status": 404, "message": "Not Found" } }
# Error getting related artists for Zohar Argov: {"error": {"status": 404, "message": "Not Found" } }
# Error getting related artists for Rob de Nijs: {"error": {"status": 404, "message": "Not Found" } }
#
# Gerelateerde artiesten voor Arik Einstein:
#
# Gerelateerde artiesten voor Zohar Argov:
#
# Gerelateerde artiesten voor Rob de Nijs:

# %%
import requests
import base64
import urllib.parse

# Spotify API credentials
CLIENT_ID = "dd4776b20a1947b692250c764d2b1564"
CLIENT_SECRET = "7e10824397094006b6d54c2f9c65edb9"

def get_access_token():
    auth_url = "https://accounts.spotify.com/api/token"
    auth_header = base64.b64encode(f"{CLIENT_ID}:{CLIENT_SECRET}".encode()).decode()

    headers = {
        "Authorization": f"Basic {auth_header}",
        "Content-Type": "application/x-www-form-urlencoded"
    }

    data = {
        "grant_type": "client_credentials"
    }

    response = requests.post(auth_url, headers=headers, data=data)
    if response.status_code == 200:
        return response.json().get("access_token")
    else:
        print("Error getting token:", response.text)
        return None

def get_artist_id(name, token):
    url = "https://api.spotify.com/v1/search"
    headers = {
        "Authorization": f"Bearer {token}"
    }
    params = {
        "q": name,
        "type": "artist",
        "limit": 1
    }

    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        data = response.json()
        items = data["artists"]["items"]
        if items:
            return items[0]["id"]
        else:
            print(f"Artist not found: {name}")
            return None
    else:
        print(f"Error searching artist {name}: {response.text}")
        return None

def get_top_tracks(artist_name, token, market="NL"):
    artist_id = get_artist_id(artist_name, token)
    if not artist_id:
        return []

    url = f"https://api.spotify.com/v1/artists/{artist_id}/top-tracks"
    headers = {
        "Authorization": f"Bearer {token}"
    }
    params = {
        "market": market
    }

    response = requests.get(url, headers=headers, params=params)
    if response.status_code == 200:
        data = response.json()
        return [track["name"] for track in data["tracks"][:5]]
    else:
        print(f"Error getting top tracks for {artist_name}: {response.text}")
        return []

def find_related_artists(artist_name, token):
    artist_id = get_artist_id(artist_name, token)
    if not artist_id:
        return []

    url = f"https://api.spotify.com/v1/artists/{artist_id}/related-artists"
    headers = {
        "Authorization": f"Bearer {token}"
    }

    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        data = response.json()
        return [artist["name"] for artist in data["artists"][:3]]  # Get 3 related artists per favorite artist
    else:
        print(f"Error getting related artists for {artist_name}: {response.text}")
        return []

# Step 1: Authenticate
access_token = get_access_token()

# Step 2: Favorite artists
favorite_artists = ["Arik Einstein", "Zohar Argov", "Rob de Nijs"]

# Step 3: Get top tracks of favorite artists
playlist_tracks = []
for artist in favorite_artists:
    playlist_tracks.extend(get_top_tracks(artist, access_token))

# Step 4: Find related artists and their top tracks
related_artists = []
for artist in favorite_artists:
    related_artists.extend(find_related_artists(artist, access_token))

# Step 5: Get top tracks of related artists
for artist in related_artists:
    playlist_tracks.extend(get_top_tracks(artist, access_token))

# Remove duplicates
playlist_tracks = list(set(playlist_tracks))

# Step 6: Create a Spotify search URL for easy playlist creation
search_query = " OR ".join(playlist_tracks[:10])  # Only first 10 tracks to avoid URL length issues
spotify_search_url = f"https://open.spotify.com/search/{urllib.parse.quote(search_query)}"

# Print results
print("\n🎵 Your Spotify Playlist - Top Tracks 🎵")
for idx, track in enumerate(playlist_tracks, 1):
    print(f"{idx}. {track}")

print(f"\n🔗 Open this link to find and add these songs to a playlist: {spotify_search_url}")
# Out:
# Error getting related artists for Arik Einstein: {"error": {"status": 404, "message": "Not Found" } }
# Error getting related artists for Zohar Argov: {"error": {"status": 404, "message": "Not Found" } }
# Error getting related artists for Rob de Nijs: {"error": {"status": 404, "message": "Not Found" } }
#
# 🎵 Your Spotify Playlist - Top Tracks 🎵
# 1. Malle Babbe
# 2. צל עץ תמר ואור ירח
# 3. Zondag
# 4. בדד
# 5. Foto Van Vroeger
# 6. נכון להיום
# 7. סע לאט
# 8. אלינור
# 9. גיטרה וכינור
# 10. Het Werd Zomer
# 11. אהבה ממבט ראשון
# 12. הפרח בגני
# 13. יש בי אהבה
# 14. אני ואתה
# 15. Banger Hart
#
# ...

# %% [markdown]
# ## Playlists
#
# The `sp.featured_playlists()` method in `spotipy` fetches a list of Spotify's featured playlists at a given moment. These are curated playlists that Spotify often highlights on the platform's homepage. The method provides a snapshot of the playlists that are being promoted or featured by Spotify at the time of the request.
#
# Once you've fetched the featured playlists, you can extract their IDs (and other details).

# %% [markdown]
# ### Getting a Playlist's Details
# To fetch details about a specific playlist, you can use the playlist method. You'll need the playlist's Spotify ID.

# %% [markdown]
# In this example, we will use the following playlist id: *37i9dQZF1DXd9zR7tdziuQ*

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd

# Replace these with your own client_id and client_secret
CLIENT_ID = "dd4776b20a1947b692250c764d2b1564"
CLIENT_SECRET = "7e10824397094006b6d54c2f9c65edb9"
REDIRECT_URI = 'http://localhost:8080'

# Authenticate with Spotify
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=CLIENT_ID,
                                                client_secret=CLIENT_SECRET,
                                                redirect_uri=REDIRECT_URI,
                                                scope="playlist-read-private"))

# Fetch the user's playlists
playlists = sp.current_user_playlists()

# Prepare list of playlist details
playlist_data = []
for playlist in playlists['items']:
    playlist_data.append({
        'Name': playlist['name'],
        'ID': playlist['id'],
        'Description': playlist.get('description', 'No description'),
        'Owner': playlist['owner']['display_name'],
        'Total Tracks': playlist['tracks']['total']
    })

# Convert to DataFrame
df_playlists = pd.DataFrame(playlist_data)

# Display the DataFrame
print(df_playlists)
# Out:
#                                       Name                      ID  \
# 0                   My top tracks playlist  2D6Q15Tsf7C1pkkH6n19hq
# 1                          Simons Playlist  3OzeLTtZ1STrzNhYZhPusb
# 2                   70's Funky Jazz Fusion  5TNGJeYkQvZBzuj2LiDxlP
# 3   Sly & The Family Stone - Greatest Hits  1zt0DU3WTrrZkvVQP1BTui
# 4                   Mario’s bachelorparteh  0fUUqQwfJgZKAgwCYxmJFg
# 5                         My Shazam Tracks  4iDwhEbvIJdTwMvQt1uIos
# 6                          Editing music 🎤  2A7NRmF7pDQs0uOcF80WAf
# 7                             Hebrew House  02vWFuc27mv3nqq55YBS2h
# 8                      Local Drank nummers  3tY4eQLWrmownpTUhP5JQB
# 9                                   Israel  4TQ0qGnDOEjLV4JdxmGtyo
# 10                       Venus en de waard  29roHP9PxBclePkoNYfGO1
# 11                                Hamelach  0cIsBtDUWq6osmqLk6OB55
# 12                     Mijn Shazam-nummers  6JeWnGc2ydJntu6giQkYtc
# ...

# %%
print(playlist['name'])  # Print the playlist's name
print(playlist['description'])  # Print the playlist's description
# Out:
# 1.

# %% [markdown]
# ### Getting Tracks from a Playlist
# If you want to get the tracks from a specific playlist, you can use the playlist_tracks method.

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd

# Replace these with your own client_id and client_secret
CLIENT_ID = "dd4776b20a1947b692250c764d2b1564"
CLIENT_SECRET = "7e10824397094006b6d54c2f9c65edb9"
REDIRECT_URI = 'http://localhost:8080'

# Authenticate with Spotify
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=CLIENT_ID,
                                                client_secret=CLIENT_SECRET,
                                                redirect_uri=REDIRECT_URI,
                                                scope="playlist-read-private"))

# Playlist ID (replace with the ID of the playlist you're interested in)
playlist_id = "29roHP9PxBclePkoNYfGO1"  # Example playlist ID

# Fetch the tracks from the playlist
tracks = sp.playlist_tracks(playlist_id)

# Prepare list of track details
track_data = []
for track in tracks['items']:
    track_data.append({
        'Track Name': track['track']['name'],
        'Artist(s)': ', '.join([artist['name'] for artist in track['track']['artists']]),
        'Album': track['track']['album']['name'],
        'Track URL': track['track']['external_urls']['spotify'],
        'Track ID': track['track']['id']
    })

# Convert to DataFrame
df_tracks = pd.DataFrame(track_data)

# Display the DataFrame
print(df_tracks)
# Out:
#                                   Track Name  \
# 0                                Cissy Strut
# 1                            Feelin' Alright
# 2          Bad Moon Rising - Remastered 1985
# 3                         Long Train Runnin'
# 4                                    Cocaine
# 5                        Hold On, I'm Comin'
# 6                                  Get It On
# 7                          Lola - Remastered
# 8                                 Radar Love
# 9                                Oerend Hard
# 10                           Born To Be Wild
# 11                                  Misirlou
# 12                            Jailhouse Rock
# 13                                 Hound Dog
# 14                           Johnny B. Goode
# 15                     Play That Funky Music
# 16            Uptown Funk (feat. Bruno Mars)
# 17          I Heard It Through The Grapevine
# 18                          Express Yourself
# 19                                 Low Rider
# ...

# %% [markdown]
# ### Getting Artists from a Playlist
#
# To extract all the artists from the tracks in a playlist, you'd typically follow these steps:
#
# 1. Fetch the playlist's tracks.
# 2. Iterate through each track.
# 3. For each track, extract the associated artists.

# %%
# List to store unique artist names
artists_list = []

for track_item in tracks['items']:
    track = track_item['track']
    for artist in track['artists']:
        artist_name = artist['name']
        if artist_name not in artists_list:  # This ensures each artist is added only once
            artists_list.append(artist_name)

print(artists_list)
# Out:
# ['The Meters', 'Joe Cocker', 'Creedence Clearwater Revival', 'The Doobie Brothers', 'J.J. Cale', 'Sam & Dave', 'T. Rex', 'The Kinks', 'Golden Earring', 'Normaal', 'Steppenwolf', 'Dick Dale', 'Elvis Presley', 'Chuck Berry', 'Wild Cherry', 'Mark Ronson', 'Bruno Mars', 'Charles Wright & The Watts 103rd Street Rhythm Band', 'War', 'Doe Maar', 'Shocking Blue', 'Santana', 'John Denver', 'Prince', 'Meat Loaf', 'Queen']

# %% [markdown]
# ## Exercise 2: Unraveling the World of Playlists
#
#
# 1. **Featured Exploration**:
#    - Fetch the list of Spotify's current featured playlists.
#    - Extract and display the names and IDs of the top 5 featured playlists.
#
# 2. **Deep Dive**:
#    - Choose any one of the top 5 featured playlists (you can choose the one you personally find most interesting or simply pick one randomly).
#    - Fetch and display its name, description, and total track count.
#
# 3. **Track-tastic**:
#    - Extract and display the names of the first 10 tracks in the chosen playlist.
#
# 4. **Artistic Flair**:
#    - Create a dictionary where the keys are the names of the first 10 tracks, and the values are lists containing the names of the artists associated with each track.
#    - For example: `{"TrackName1": ["Artist1", "Artist2"], "TrackName2": ["Artist3"]}`

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# Replace these with your own client_id and client_secret
CLIENT_ID = "dd4776b20a1947b692250c764d2b1564"
CLIENT_SECRET = "7e10824397094006b6d54c2f9c65edb9"
REDIRECT_URI = 'http://localhost:8080'

# Authenticate with Spotify
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=CLIENT_ID,
                                                client_secret=CLIENT_SECRET,
                                                redirect_uri=REDIRECT_URI,
                                                scope="playlist-read-private"))

# Function to fetch tracks from a playlist
def get_playlist_tracks(playlist_id):
    try:
        playlist_tracks = sp.playlist_tracks(playlist_id)
        return playlist_tracks['items']
    except Exception as e:
        print(f"Error fetching tracks for playlist {playlist_id}: {e}")
        return []

# Example playlist IDs
playlist_ids = ["1jJ6s5Oa4tZ6v3zQFZ6YOK", "37i9dQZF1DX0XUsuxWHRQd"]  # Use correct public playlist IDs

for playlist_id in playlist_ids:
    tracks = get_playlist_tracks(playlist_id)
    if tracks:
        print(f"Tracks from playlist {playlist_id}:")
        for track in tracks:
            track_name = track['track']['name']
            artists = ', '.join([artist['name'] for artist in track['track']['artists']])
            print(f" - {track_name} by {artists}")
    else:
        print(f"No tracks found for playlist {playlist_id}")
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/playlists/1jJ6s5Oa4tZ6v3zQFZ6YOK/tracks with Params: {'limit': 100, 'offset': 0, 'fields': None, 'market': None, 'additional_types': 'track'} returned 404 due to Resource not found
# Error fetching tracks for playlist 1jJ6s5Oa4tZ6v3zQFZ6YOK: http status: 404, code: -1 - https://api.spotify.com/v1/playlists/1jJ6s5Oa4tZ6v3zQFZ6YOK/tracks?limit=100&offset=0&additional_types=track:
#  Resource not found, reason: None
# No tracks found for playlist 1jJ6s5Oa4tZ6v3zQFZ6YOK
# HTTP Error for GET to https://api.spotify.com/v1/playlists/37i9dQZF1DX0XUsuxWHRQd/tracks with Params: {'limit': 100, 'offset': 0, 'fields': None, 'market': None, 'additional_types': 'track'} returned 404 due to Resource not found
# Error fetching tracks for playlist 37i9dQZF1DX0XUsuxWHRQd: http status: 404, code: -1 - https://api.spotify.com/v1/playlists/37i9dQZF1DX0XUsuxWHRQd/tracks?limit=100&offset=0&additional_types=track:
#  Resource not found, reason: None
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd

# Replace these with your own client_id and client_secret
CLIENT_ID = "your_client_id"
CLIENT_SECRET = "your_client_secret"
REDIRECT_URI = 'http://localhost:8080'

# Authenticate with Spotify
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=CLIENT_ID,
                                                client_secret=CLIENT_SECRET,
                                                redirect_uri=REDIRECT_URI,
                                                scope="playlist-read-private"))

# Fetch the user's playlists
playlists = sp.current_user_playlists()

# Prepare list of playlist details
playlist_data = []
for playlist in playlists['items']:
    playlist_data.append({
        'Name': playlist['name'],
        'ID': playlist['id'],
        'Description': playlist.get('description', 'No description'),
        'Owner': playlist['owner']['display_name'],
        'Total Tracks': playlist['tracks']['total']
    })

# Convert to DataFrame
df_playlists = pd.DataFrame(playlist_data)

# Display the DataFrame
print(df_playlists)
# Out:
#                                       Name                      ID  \
# 0                   My top tracks playlist  2D6Q15Tsf7C1pkkH6n19hq
# 1                          Simons Playlist  3OzeLTtZ1STrzNhYZhPusb
# 2                   70's Funky Jazz Fusion  5TNGJeYkQvZBzuj2LiDxlP
# 3   Sly & The Family Stone - Greatest Hits  1zt0DU3WTrrZkvVQP1BTui
# 4                   Mario’s bachelorparteh  0fUUqQwfJgZKAgwCYxmJFg
# 5                         My Shazam Tracks  4iDwhEbvIJdTwMvQt1uIos
# 6                          Editing music 🎤  2A7NRmF7pDQs0uOcF80WAf
# 7                             Hebrew House  02vWFuc27mv3nqq55YBS2h
# 8                      Local Drank nummers  3tY4eQLWrmownpTUhP5JQB
# 9                                   Israel  4TQ0qGnDOEjLV4JdxmGtyo
# 10                       Venus en de waard  29roHP9PxBclePkoNYfGO1
# 11                                Hamelach  0cIsBtDUWq6osmqLk6OB55
# 12                     Mijn Shazam-nummers  6JeWnGc2ydJntu6giQkYtc
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth

# Replace these with your own client_id and client_secret
CLIENT_ID = "your_client_id"
CLIENT_SECRET = "your_client_secret"
REDIRECT_URI = 'http://localhost:8080'

# Authenticate with Spotify
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=CLIENT_ID,
                                                client_secret=CLIENT_SECRET,
                                                redirect_uri=REDIRECT_URI,
                                                scope="playlist-read-private"))

# Replace with your own playlist ID (for example, 'My Top Tracks' playlist)
playlist_id = '2D6Q15Tsf7C1pkkH6n19hq'  # Example playlist ID (change to your playlist)

# Fetch the tracks in the playlist (first 10 tracks)
tracks = sp.playlist_tracks(playlist_id, limit=10)  # Get the first 10 tracks

# Create dictionary with track names as keys and associated artists as values
track_artists = {}
for track in tracks['items']:
    track_name = track['track']['name']
    artists = [artist['name'] for artist in track['track']['artists']]
    track_artists[track_name] = artists

# Display the dictionary
print(track_artists)
# Out:
# {'עוד פגישה': ['T-Slam'], 'הכוכבים דולקים על אש קטנה': ['Mashina'], 'על קו הזינוק': ['The Friends of Natasha'], 'Dean Town': ['Vulfpeck'], 'שש עשרה מלאו לנער': ['Gabi Shoshan']}
